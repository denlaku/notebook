# %%
import numpy as np

sample = np.random.randint(low=1,high=100,size=10)
sample
[np.random.choice(sample, size=sample.shape) for i in range(100)]
# Out:
# [array([ 6, 17, 27, 91, 33, 91, 33, 94, 33, 27]),
#  array([94, 27, 17, 17, 27, 36, 70, 27, 27, 49]),
#  array([27, 94, 45, 49, 70, 94, 36, 27, 33,  6]),
#  array([27, 36, 36,  6, 70, 27, 27, 33, 36, 45]),
#  array([17, 49, 33, 91, 94,  6, 36, 27,  6, 91]),
#  array([17, 27, 33, 36, 94, 17, 27,  6, 49,  6]),
#  array([ 6,  6, 27,  6, 49, 45, 94, 27, 36, 49]),
#  array([ 6, 49, 91, 27, 94, 45, 94, 94, 70, 33]),
#  array([33, 91,  6,  6, 91, 91, 49, 33, 45, 94]),
#  array([49, 27, 36,  6, 45, 17, 70, 27, 91, 36]),
#  array([27,  6, 45, 49, 17,  6, 36, 70, 45, 33]),
#  array([ 6, 70, 33, 70, 94, 45,  6, 36, 45, 17]),
#  array([17, 27, 91, 36, 33, 45, 49, 91, 70, 91]),
#  array([45, 94, 70, 94, 94, 36, 94, 49, 33, 49]),
#  array([45,  6, 45, 33, 91, 49, 70, 49, 94, 70]),
#  array([94, 94, 27, 49, 33,  6, 17, 45, 45, 70]),
#  array([70, 70, 36, 94, 27, 94,  6, 45, 70, 33]),
#  array([45, 17, 27, 91, 49, 17,  6, 91, 45, 70]),
#  array([ 6, 27,  6, 27, 27, 91, 49, 70, 33, 17]),
# ...
