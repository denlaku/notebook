# %%
import pyhdfs
from pyhdfs import HdfsClient

hosts = '10.10.10.11:50070'

fs = HdfsClient(hosts)

class Hdfs:
    def __init__(self, hosts):
        self.fs = HdfsClient(hosts)
    
    def mkdirs(self, path):
        self.fs.mkdirs(path)
        
    def upload(self, fileName, target):
        self.fs.copy_from_local(fileName, target)
        
    def delete(self, path):
        self.fs.delete(path)
        
# hdfs = Hdfs(hosts)

# hdfs.upload('presto.jar', '/pyhdfs/presto.jar')
# hdfs.delete('/pyhdfs/presto.jar')
# hdfs.delete('/pyhdfs/temp1')

# fs.create*?
# ?fs.create
# ?fs.append
# ?fs.copy_from_local
# fs.hosts
# fs.user_name
# ?fs.list_status
# ?fs.listdir
# ?fs.concat
dir(fs)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_delete',
#  '_get',
#  '_last_time_recorded_active',
#  '_parse_hosts',
#  '_parse_path',
#  '_post',
#  '_put',
#  '_record_last_active',
#  '_request',
#  '_requests_kwargs',
#  '_requests_session',
#  'append',
#  'concat',
#  'copy_from_local',
#  'copy_to_local',
#  'create',
#  'create_snapshot',
#  'create_symlink',
#  'delete',
#  'delete_snapshot',
#  'exists',
#  'get_active_namenode',
#  'get_content_summary',
#  'get_file_checksum',
#  'get_file_status',
#  'get_home_directory',
#  'get_xattrs',
#  'hosts',
#  'list_status',
#  'list_xattrs',
#  'listdir',
#  'max_tries',
#  'mkdirs',
#  'open',
#  'randomize_hosts',
#  'remove_xattr',
#  'rename',
#  'rename_snapshot',
#  'retry_delay',
#  'set_owner',
#  'set_permission',
#  'set_replication',
#  'set_times',
#  'set_xattr',
#  'timeout',
#  'user_name',
#  'walk']
